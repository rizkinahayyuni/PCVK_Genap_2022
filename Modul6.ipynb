# %% [markdown]
# <a href="https://colab.research.google.com/github/rizkinahayyuni/PCVK_Genap_2022/blob/main/Modul6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Praktikum**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
import math
import osgeo
import glob

# %% [markdown]
# **Histogram Citra**

# %%
img_lena = cv.imread('/content/drive/MyDrive/DATA/lena.jpg')

# Menghitung pixel warna RED([2]), mask = none, histSize(histogram sizes in each dimension) = 256, range = [0-256]
hist_r = cv.calcHist([img_lena],[2],None,[256],[0,256])     
# Menghitung pixel warna GREEN([1]), mask = none, histSize(histogram sizes in each dimension) = 256, range = [0-256]
hist_g = cv.calcHist([img_lena],[1],None,[256],[0,256])     
# Menghitung pixel warna BLUE([0]), mask = none, histSize(histogram sizes in each dimension) = 256, range = [0-256]
hist_b = cv.calcHist([img_lena],[0],None,[256],[0,256])     

fig, (ax_r, ax_g, ax_b) = plt.subplots(1, 3, figsize=[15,4], sharex=True, sharey=True)  # Membuat plot 1baris & 3kolom
fig.suptitle('Histogram RGB plot')                                                      # Menambahkan title dari plot
fig.text(0.08, 0.45, 'Jumlah Kemunculan', va='center', rotation='vertical')      # atribut(x, y, text, text_properties)
fig.text(0.5, 0.03, 'Intensitas Warna', ha='center')                             # atribut(x, y, text, text_properties)
ax_r.plot(hist_r, color='red')                    # Membuat plot untuk histogram warna merah
ax_g.plot(hist_g, color='green')                  # Membuat plot untuk histogram warna merah
ax_b.plot(hist_b, color='blue')                   # Membuat plot untuk histogram warna merah

# %% [markdown]
# **Histogram Citra dengan Numpy Histogram**

# %%
rgb_lena2 = img_lena          # Copy img_lena

# Mencari dan membuat plot dari hasil Histogram
# Penggunaan ravel() untuk perataan array sehingga dapat langsung dilakukan plotting
# 256 adalah nilai untuk bins(jumlah rentang data)
bin_counts, bin_edges, patches = plt.hist(rgb_lena2.ravel(), 256)       

# saya tidak menemukan sumber bahwa dengan menggunakan np.histogram dapat menampilkan histogram dari masing masing warna RGB.
# Sejauh informasi yang saya dapatkan penggunaan np.histogram banyak digunakan untuk gambar grayscale

# %% [markdown]
# **SUMBER BAHAN AJAR**
# 1. https://pyimagesearch.com/2021/04/28/opencv-image-histograms-cv2-calchist/
# 2. https://www.geeksforgeeks.org/python-opencv-cv2-calchist-method/
# 3. https://www.geeksforgeeks.org/matplotlib-figure-figure-text-in-python/
# 4. https://stackoverflow.com/questions/29864330/histogram-of-gray-scale-values-in-numpy-image
# 5. https://datacarpentry.org/image-processing/05-creating-histograms/
